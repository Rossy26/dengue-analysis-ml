# %% [markdown]
# # Proyecto final inteligencia artificial 2025-II
#
# ##
# Este proyecto tiene como fin explorar el comportamiento de los casos de dengue con los datasets que nos da la página oficial del sivigila para los años 2022-2024
# https://portalsivigila.ins.gov.co/Paginas/Buscador.aspx
#
# TODO expandir esto

# %% [markdown]
# ## Introducción
# TODO hacer esto al final

# %% [markdown]
# ## Metodología

# %% [markdown]
# ### Uniendo DataSets
# Dado que los 3 datasets están separados se optó por unirlos
#
# Un problema que esto ocaciona es que el dataset del año 2024 tiene 72 columnas y los otros dos tienen 73
#
# Al no poder imputar esta columna completa en el dataset del año 2024, se optó por borrarlas de los otros dos datasets

# %%
# cargar las tres datas

# %%
# unirlas en una sola

# %% [markdown]
# ### Visualización de los datos

# %% [markdown]
# #### Gráfica x para demostrar x

# %% [markdown]
# #### Gráfica y para demostrar o ver la dispersión

# %% [markdown]
# ### Preprocesamiento

# %% [markdown]
# #### Técnica 1 de preprocesamiento aplicada:
# ##### Nombre de la técnica

# %%
# Código de la técnica

# %% [markdown]
# #### Técnica 2 de preprocesamiento aplicada:
# ##### Nombre de la técnica

# %%
# Código de la técnica

# %% [markdown]
# ### Selección de características

# %% [markdown]
# ### Entrenamiento de los modelos

# %% [markdown]
# #### Random Forest

# %% [markdown]
# ### Evaluación de los modelos

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# ## Trabajo futuro
